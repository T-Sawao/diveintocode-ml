# %% [markdown]
# **曽呂利新左衛門問題**

# %% [markdown]
# # 【問題1】100日目の米粒の数

# %% [markdown]
# 100日目には合計で米粒をいくつもらっているのかを計算するコードを作成し、答えを出力してください。また、1日目から100日目までの「その日にもらう米の数」と「その日までに累計で貰う米の数」の推移を折れ線グラフで表現してください。（縦軸が米の数、横軸が日数）

# %% [markdown]
# ## 【課題１−１】 100日目には合計で米粒をいくつもらえるか。

# %%
rice_data = [] # 日毎の貰える米数のリスト
rice_total = [] # 貰える米数の累計リスト
day_list = [i+1 for i in range(100)] #日数のリスト
x = 0 #米の累計値計算の初期値

#計算式(詳細は下記の解説１を参照)
for i in range(100):
  y = 1 * 1 * (2**i) 
  x += y
  rice_data.append(y)
  rice_total.append(x)

print(f"100日目に貰える米粒の合計数は{rice_total[100-1]}粒です。")
# Out:
# 100日目に貰える米粒の合計数は1267650600228229401496703205375粒です。

# %%
#計算式に等比数列を使用

rice_data = [] # 日毎の貰える米数のリスト
rice_total = [] # 貰える米数の累計リスト
day_list = [i+1 for i in range(100)] #日数のリスト
x = 0 #米の累計値計算の初期値

#計算式
for i in range(1,101):
  y = 1 * 2 ** (i-1)
  x += y
  rice_data.append(y)
  rice_total.append(x)


print(f"100日目に貰える米粒の合計数は{rice_total[100-1]}粒です。")
# Out:
# 100日目に貰える米粒の合計数は1267650600228229401496703205375粒です。

# %% [markdown]
# **※解説１ 上記の計算式について**
# $y=1 \times 1 \times2^i$
# i日目に貰える米粒数 = １日目の貰える米粒数 x 1日目 x ２倍のi乗
# $x += y$
# 米の累積数 += 日毎の貰える数
# x値とy値をそれぞれのリストに追記する。
# 上記の計算を100日分繰り返し処理を行う。

# %%
#下記は確認用コマンド
print(rice_data)
print(rice_total)
print(day_list)
print(len(rice_data))
print(len(rice_total))
print(len(day_list))
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, 2147483648, 4294967296, 8589934592, 17179869184, 34359738368, 68719476736, 137438953472, 274877906944, 549755813888, 1099511627776, 2199023255552, 4398046511104, 8796093022208, 17592186044416, 35184372088832, 70368744177664, 140737488355328, 281474976710656, 562949953421312, 1125899906842624, 2251799813685248, 4503599627370496, 9007199254740992, 18014398509481984, 36028797018963968, 72057594037927936, 144115188075855872, 288230376151711744, 576460752303423488, 1152921504606846976, 2305843009213693952, 4611686018427387904, 9223372036854775808, 18446744073709551616, 36893488147419103232, 73786976294838206464, 147573952589676412928, 295147905179352825856, 590295810358705651712, 1180591620717411303424, 2361183241434822606848, 4722366482869645213696, 9444732965739290427392
# ...

# %% [markdown]
# ## 【課題1-2】 100日目までの「日毎の貰える米数」と「累計の米数」の推移グラフ

# %%
import matplotlib.pyplot as plt

figue,(Left,Right) = plt.subplots(ncols=2, figsize=(10, 5))

#『日毎の貰える米数のリスト』図形の設定
Left.plot(day_list, rice_data)
Left.set_title("rice_data")
Left.set_xlabel("day")
Left.set_ylabel("rice_data")
Left.grid(True)

#『貰える米数の累計リスト』図形の設定
Right.plot(day_list, rice_total)
Right.set_title("rice_total")
Right.set_xlabel("day")
Right.set_ylabel("rice_total")
Right.grid(True)

figue.show()
# Out:
# <ipython-input-4-5b8409f05750>:19: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figue.show()

# %% [markdown]
# # 【問題2】100日目以外の米粒の数

# %% [markdown]
# この逸話は30日だったり81日だったりと日数が曖昧です。どの話にも対応できるように日数を引数とした 関数 を作成しましょう。関数を作成した上で、コースを受講する日数の間でいくつ米粒をもらえるかを答えてください。前の問題同様に折れ線グラフも出力してください。
# 以下の雛形には関数としての枠組みだけではなく、引数や返り値についてのコメントも記載してあります。参考にして、自分なりにも分かりやすくコメントを書き換えてください。

# %% [markdown]
# ## 【課題2-1】 関数の作成

# %%
def compute_sorori_shinzaemon(day=100):
  rice_data = [] # 日毎の貰える米数のリスト
  rice_total = [] # 貰える米数の累計リスト
  day_list = [i+1 for i in range(day)] #日数のリスト
  x = 0 #米の累計値計算の初期値

# 問１の計算式を流用
  for i in range(day):
    y = 1 * 1 * (2**i)
    x += y
    rice_data.append(y)
    rice_total.append(x)
  return rice_data, rice_total, day_list

# %%
#計算式に等比数列を使用

def compute_sorori_shinzaemon(day=100):
  rice_data = [] # 日毎の貰える米数のリスト
  rice_total = [] # 貰える米数の累計リスト
  day_list = [i+1 for i in range(day)] #日数のリスト
  x = 0 #米の累計値計算の初期値

# 問１の計算式を流用
  for i in range(1, day+1):
    y = 1 * 2 **(i-1)
    x += y
    rice_data.append(y)
    rice_total.append(x)
  return rice_data, rice_total, day_list

# %% [markdown]
# ## 【課題2-2】 課題2-1の関数でコース日数(123日間)を適用しよう。

# %%
#例外処理(詳細は下記の解説２を参照)
day = None
try: 
  day =int(input("MLコースの日数分を知りたいときは、0と入力してください。 それ以外の日数が知りたい時は日数を数字で記入ください : "))
except ValueError as e: 
  print("マイナスの日数や数字以外では計算できません、正の数字を入力してください。") 

# MLコース希望で、00と入力された場合の条件式
if day == 0:
  day = 123 #123日は４ヶ月間の日数です
else:
  pass

rice_data, rice_total, day_list = compute_sorori_shinzaemon(day) #各変数に『曽呂利新左衛門』関数の戻り値を代入する。
print(f"{day}日目に貰える米粒の合計数は{rice_total[day-1]}粒です。")
# Out:
# MLコースの日数分を知りたいときは、0と入力してください。 それ以外の日数が知りたい時は日数を数字で記入ください :  0
# 123日目に貰える米粒の合計数は10633823966279326983230456482242756607粒です。

# %%
# 確認用コマンド
print(rice_data)
print(rice_total)
print(day_list)
print(len(rice_data))
print(len(rice_total))
print(len(day_list))
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, 2147483648, 4294967296, 8589934592, 17179869184, 34359738368, 68719476736, 137438953472, 274877906944, 549755813888, 1099511627776, 2199023255552, 4398046511104, 8796093022208, 17592186044416, 35184372088832, 70368744177664, 140737488355328, 281474976710656, 562949953421312, 1125899906842624, 2251799813685248, 4503599627370496, 9007199254740992, 18014398509481984, 36028797018963968, 72057594037927936, 144115188075855872, 288230376151711744, 576460752303423488, 1152921504606846976, 2305843009213693952, 4611686018427387904, 9223372036854775808, 18446744073709551616, 36893488147419103232, 73786976294838206464, 147573952589676412928, 295147905179352825856, 590295810358705651712, 1180591620717411303424, 2361183241434822606848, 4722366482869645213696, 9444732965739290427392
# ...

# %% [markdown]
# **※解説２ 例外処理について**
# 知りたい日数(変数day)を標準入力で受ける処理をしているため、その処理に対して例外処理を行っています。
# 正の数字以外が入力された場合は、

# %% [markdown]
# ## 【課題2-3】 課題2-3の場合の「日毎の貰える米数」と「累計の米数」の推移グラフ

# %%
import matplotlib.pyplot as plt

figue,(Left,Right) = plt.subplots(ncols=2, figsize=(10, 5))

#『日毎の貰える米数のリスト』図形の設定
Left.plot(day_list, rice_data)
Left.set_title("rice_data")
Left.set_xlabel("day_list")
Left.set_ylabel("rice_data")
Left.grid(True)

#『貰える米数の累計リスト』図形の設定
Right.plot(day_list, rice_total)
Right.set_title("rice_total")
Right.set_xlabel("day_list")
Right.set_ylabel("rice_total")
Right.grid(True)

figue.show()
# Out:
# <ipython-input-9-ee81ffbbadba>:19: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figue.show()

# %% [markdown]
# # 【問題3】貰える米で何人が何日生活できるか

# %% [markdown]
# この米があれば何人が何日生活できるか計算する関数を作成してください。コースを受講する期間に貰える米粒で、このクラスにいる人数であれば、何日間生活できるかを出力してみましょう。
# 関数の最低限の入力は 米粒の数(int) と 人数(int) 、出力は 生活できる日数(int) です。関数名やコメントなどは分かりやすく考えて作成してください。
# ここでは1日に必要な米粒の数は提示しません。自分なりに調べて、計算式に落とし込んでください。どう調べ、何を根拠にしたかもコメントを残しておいてください。

# %% [markdown]
# ## 【課題3-1】 米の数字データの検証

# %% [markdown]
# 今回のすべての米の計算に関するデータは、炊飯器の大手メーカーTIGER様より流用しました。
# https://www.tiger.jp/feature/ricecooker/curiosity/vol06.html
#
# 信頼に値する根拠としては、今回使用した数字データ以外にも細かな数字データを扱っている点と企業としての社会的信用の部分からこちらのデータを使用しました。
# 1合=6483粒 江戸時代より伝わる語呂合わせを参照。
# 1合=約150g
#  炊きあがり時には1.33倍に増える。

# %% [markdown]
# ## 【課題3-2】　コース受講期間における受給米で何日生活できるか。

# %% [markdown]
# **補足事項**
# ・コース受講期間は、10/1〜1/31までの123日とする。
# ・受講人数はML2010期生の9人とする。
# ・毎日３杯のご飯を食べるものとする。

# %%
#rice_life関数は、引数(人数, ご飯の何杯/日, 日数)から、何日生活出来るかを戻り値として返します。
def rice_life(ninzu, nanbai, day): 
  rice_total = 0 #米の在庫数の初期値
  for i in range(day):
    y = 1 * 1 * (2**i)
    rice_total += y    # 米の在庫数(単位は粒)

  one_gou = 6483 # 1合は6483粒
  g = 150 * 1.33    # 1合は150g、但し炊きあがり時点では水分を吸い約1.33倍になる。
  rice_total_g = rice_total * g / one_gou
  #△米の在庫数(単位はg)  粒単位からg単位に変換する式
  one_cup = 180 #お茶碗１杯の消費g数
  syouhi = int(ninzu) * int(nanbai) * one_cup
  life_day = rice_total_g / syouhi
  #△何日生活出来るかを、米の在庫数(g)から人数、杯数、日数から算出する式
  return rice_total, rice_total_g, syouhi, life_day

# 標準入力
print("倍々になるお米があれば何人で、何日間生活出来るか計算するために、３つの質問にお答えください！！")
ninzu = int(input("何人家族ですか？             "))
nanbai = int(input("１日に何杯のご飯を食べますか？ "))
day = int(input("何日間で計算しますか？       "))

rice_total, rice_total_g, syouhi, life_day = rice_life(ninzu, nanbai, day)
print(f"{day}日間で貰えるの米粒は、{rice_total}粒で、{rice_total_g:.1f}gです。{ninzu}人で１日{nanbai}杯食べると1日にお米{syouhi}g消費するので、{life_day:.0f}日間生活していくことが出来ます。")
# Out:
# 倍々になるお米があれば何人で、何日間生活出来るか計算するために、３つの質問にお答えください！！
# 何人家族ですか？              9
# １日に何杯のご飯を食べますか？  3
# 何日間で計算しますか？        123
# 123日間で貰えるの米粒は、10633823966279326983230456482242756607粒で、327232435797119507587040100908793856.0gです。9人で１日3杯食べると1日にお米4860g消費するので、67331776912987555989021666574336日間生活していくことが出来ます。

# %%
#rice_life関数は、引数(人数, ご飯の何杯/日, 日数)から、何日生活出来るかを戻り値として返します。
def rice_life(ninzu, nanbai, day): 
  rice_total = 0 #米の在庫数の初期値
  for i in range(1, day+1):
    y = 1 * 2 ** (i-1)
    rice_total += y    # 米の在庫数(単位は粒)

  one_gou = 6483 # 1合は6483粒
  g = 150 * 1.33    # 1合は150g、但し炊きあがり時点では水分を吸い約1.33倍になる。
  rice_total_g = rice_total * g / one_gou
  #△米の在庫数(単位はg)  粒単位からg単位に変換する式
  one_cup = 180 #お茶碗１杯の消費g数
  syouhi = int(ninzu) * int(nanbai) * one_cup
  life_day = rice_total_g / syouhi
  #△何日生活出来るかを、米の在庫数(g)から人数、杯数、日数から算出する式
  return rice_total, rice_total_g, syouhi, life_day

# 標準入力
print("倍々になるお米があれば何人で、何日間生活出来るか計算するために、３つの質問にお答えください！！")
ninzu = int(input("何人家族ですか？             "))
nanbai = int(input("１日に何杯のご飯を食べますか？ "))
day = int(input("何日間で計算しますか？       "))

rice_total, rice_total_g, syouhi, life_day = rice_life(ninzu, nanbai, day)
print(f"{day}日間で貰えるの米粒は、{rice_total}粒で、{rice_total_g:.1f}gです。{ninzu}人で１日{nanbai}杯食べると1日にお米{syouhi}g消費するので、{life_day:.0f}日間生活していくことが出来ます。")
# Out:
# 倍々になるお米があれば何人で、何日間生活出来るか計算するために、３つの質問にお答えください！！
# 何人家族ですか？              9
# １日に何杯のご飯を食べますか？  3
# 何日間で計算しますか？        123
# 123日間で貰えるの米粒は、10633823966279326983230456482242756607粒で、327232435797119507587040100908793856.0gです。9人で１日3杯食べると1日にお米4860g消費するので、67331776912987555989021666574336日間生活していくことが出来ます。
